# %%
import pandas as pd
from scrappy import Scrapper

# %%
url = 'https://fbref.com/en/comps/Big5/stats/players/Big-5-European-Leagues-Stats'

headers = {
        'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.198 Safari/537.36"}

# %%
players = Scrapper(url, headers)
dicionario = players.createDict(0,3004)
df = pd.DataFrame(dicionario)

# %%
df[df['Squad'] == "Real Madrid"].head()
# Out:
#                 Player  Nation    Pos        Squad        Comp Age  Born  MP  \
# 56         David Alaba  at AUT     DF  Real Madrid  es La Liga  30  1992  23
# 138     Sergio Arribas  es ESP  MF,FW  Real Madrid  es La Liga  20  2001   2
# 148      Marco Asensio  es ESP  FW,MF  Real Madrid  es La Liga  26  1996  31
# 289      Karim Benzema  fr FRA     FW  Real Madrid  es La Liga  34  1987  24
# 439  Eduardo Camavinga  fr FRA  MF,DF  Real Madrid  es La Liga  19  2002  37
#
#     Starts    Min  ... CrdR    xG  npxG   xAG npxG+xAG PrgC PrgP PrgR G+A-PK  \
# 56      21  1,838  ...    0  0.04  0.04  0.05     0.09   16   67   60   0.20
# 138      0     19  ...    0  0.74  0.74  0.14     0.88    0    2    0   0.00
# 148     15  1,442  ...    0  0.39  0.35  0.30     0.65   56   70  108   0.94
# 289     24  2,038  ...    0  0.95  0.66  0.26     0.91   72  138  157   0.66
# 439     21  2,010  ...    0  0.04  0.04  0.07     0.10   69  165   99   0.04
#
#     xG+xAG
# 56    0.09
# 138   0.88
# 148   0.70
# 289   1.20
# 439   0.10
#
# [5 rows x 28 columns]

# %%
df.drop(['xG', 'npxG', 'xAG', 'npxG+xAG', 'PrgC', 'PrgP', 'PrgR',
       'G+A-PK', 'xG+xAG'], inplace= True, axis= 1)
df.to_csv('C:\\Users\\alexa\\OneDrive\\Documents\\a_soccer_table_scrapper\\output\\2022-2023_footbal_players_status.csv')
