# %%
import pandas as pd
from scrappy import Scrapper

# %%
url = 'https://fbref.com/en/comps/Big5/stats/players/Big-5-European-Leagues-Stats'

headers = {
        'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.198 Safari/537.36"}

# %%
players = Scrapper(url, headers)

# %%
dicionario = players.createDict(0,3004)
df = pd.DataFrame(dicionario)
df.head()
# Out:
#              Player   Nation    Pos           Squad                Comp Age  \
# 0  Brenden Aaronson   us USA  MF,FW    Leeds United  eng Premier League  21
# 1   Paxten Aaronson   us USA  MF,DF  Eint Frankfurt       de Bundesliga  18
# 2    James Abankwah   ie IRL     DF         Udinese          it Serie A  18
# 3     George Abbott  eng ENG     MF       Tottenham  eng Premier League  16
# 4  Yunis Abdelhamid   ma MAR     DF           Reims          fr Ligue 1  34
#
#    Born  MP Starts    Min  ... CrdR    xG  npxG   xAG npxG+xAG PrgC PrgP PrgR  \
# 0  2000  36     28  2,372  ...    0  0.15  0.15  0.16     0.31   43   86  151
# 1  2003   7      0    173  ...    0  0.09  0.09  0.03     0.11    8    6   15
# 2  2004   2      1     63  ...    0  0.00  0.00  0.00     0.00    0    0    0
# 3  2005   1      0      1  ...    0  0.00  0.00  0.00     0.00    0    0    0
# 4  1987  37     37  3,330  ...    0  0.06  0.06  0.03     0.09   40  215   10
#
#   G+A-PK xG+xAG
# 0   0.15   0.31
# 1   0.00   0.11
# 2   0.00   0.00
# 3   0.00   0.00
# 4   0.08   0.09
#
# [5 rows x 28 columns]

# %%
df.drop(['xG', 'npxG', 'xAG', 'npxG+xAG', 'PrgC', 'PrgP', 'PrgR',
       'G+A-PK', 'xG+xAG'], inplace= True, axis= 1)
df.to_csv('C:\\Users\\alexa\\OneDrive\\Documents\\a_soccer_table_scrapper\\output\\2022-2023_footbal_players_status.csv')

# %%
df[df['Squad'] == "Arsenal"].head(70)
# Out:
#                     Player   Nation    Pos    Squad                Comp Age  \
# 780     Gabriel Dos Santos   br BRA     DF  Arsenal  eng Premier League  24
# 838         Mohamed Elneny   eg EGY     MF  Arsenal  eng Premier League  30
# 1202           Rob Holding  eng ENG     DF  Arsenal  eng Premier League  26
# 1290         Gabriel Jesus   br BRA     FW  Arsenal  eng Premier League  25
# 1303              Jorginho   it ITA     MF  Arsenal  eng Premier League  30
# 1385          Jakub Kiwior   pl POL     DF  Arsenal  eng Premier League  22
# 1665            Marquinhos   br BRA     MF  Arsenal  eng Premier League  19
# 1678            Martinelli   br BRA     FW  Arsenal  eng Premier League  21
# 1901          Reiss Nelson  eng ENG     FW  Arsenal  eng Premier League  22
# 1925         Eddie Nketiah  eng ENG     FW  Arsenal  eng Premier League  23
# 1942         Ethan Nwaneri  eng ENG     FW  Arsenal  eng Premier League  15
# 2039         Thomas Partey   gh GHA     MF  Arsenal  eng Premier League  29
# 2189        Aaron Ramsdale  eng ENG     GK  Arsenal  eng Premier League  24
# 2326           Bukayo Saka  eng ENG     FW  Arsenal  eng Premier League  20
# 2334        William Saliba   fr FRA     DF  Arsenal  eng Premier League  21
# 2344  Albert Sambi Lokonga   be BEL     MF  Arsenal  eng Premier League  22
# 2473      Emile Smith Rowe  eng ENG  MF,FW  Arsenal  eng Premier League  22
# 2475         Cédric Soares   pt POR     DF  Arsenal  eng Premier League  30
# 2615        Kieran Tierney  sct SCO     DF  Arsenal  eng Premier League  25
# 2627     Takehiro Tomiyasu   jp JPN     DF  Arsenal  eng Premier League  23
# 2661      Leandro Trossard   be BEL     FW  Arsenal  eng Premier League  27
# 2731          Fabio Vieira   pt POR  MF,FW  Arsenal  eng Premier League  22
#
#       Born  MP Starts    Min  ... CrdR    xG  npxG   xAG npxG+xAG PrgC PrgP  \
# 780   1997  38     38  3,409  ...    0  0.13  0.13  0.01     0.14   18  153
# 838   1992   5      1    113  ...    0  0.00  0.00  0.00     0.00    1    2
# 1202  1995  14      6    566  ...    0  0.05  0.05  0.00     0.05    3   24
# 1290  1997  26     24  2,064  ...    0  0.61  0.58  0.17     0.75   44   64
# 1303  1991  14      9    855  ...    0  0.02  0.02  0.02     0.04   15   99
# 1385  2000   7      5    427  ...    0  0.02  0.02  0.01     0.03    0    6
# 1665  2003   1      0      1  ...    0  0.00  0.00  0.00     0.00    0    0
# 1678  2001  36     34  2,789  ...    0  0.30  0.30  0.29     0.59  124   94
# 1901  1999  11      0    212  ...    0  0.46  0.46  0.58     1.04   19    6
# 1925  1999  30      9  1,089  ...    0  0.68  0.68  0.11     0.78   32   15
# 1942  2007   1      0      1  ...    0  0.00  0.00  0.00     0.00    0    0
# 2039  1993  33     28  2,483  ...    0  0.08  0.08  0.06     0.14   34  231
# 2189  1998  38     38  3,420  ...    0  0.00  0.00  0.00     0.00    0    8
# 2326  2001  38     37  3,181  ...    0  0.32  0.26  0.24     0.50  179  109
# 2334  2001  27     27  2,415  ...    0  0.03  0.03  0.04     0.08   13   99
# 2344  1999   6      2    198  ...    0  0.00  0.00  0.01     0.01    0   12
# 2473  2000  12      0    172  ...    0  0.14  0.14  0.36     0.50    2    7
# 2475  1991   2      0     29  ...    0  0.00  0.00  0.00     0.00    1    3
# 2615  1997  27      6    795  ...    0  0.04  0.04  0.04     0.08   25   36
# 2627  1998  21      6    663  ...    0  0.03  0.03  0.08     0.11   14   51
# 2661  1994  20     10    931  ...    0  0.18  0.18  0.46     0.64   36   57
# 2731  2000  22      3    514  ...    0  0.15  0.15  0.44     0.58    8   35
#
#      PrgR G+A-PK xG+xAG
# 780    16   0.08   0.14
# 838     1   0.00   0.00
# 1202    2   0.16   0.05
# 1290  194   0.70   0.78
# 1303    8   0.11   0.04
# 1385    6   0.21   0.03
# 1665    0   0.00   0.00
# 1678  350   0.65   0.59
# 1901   34   2.12   1.04
# 1925   82   0.41   0.78
# 1942    0   0.00   0.00
# 2039   35   0.11   0.14
# 2189    0   0.00   0.00
# 2326  520   0.65   0.56
# 2334    2   0.11   0.08
# 2344    2   0.00   0.01
# 2473   11   1.05   0.50
# 2475    0   0.00   0.00
# 2615   31   0.11   0.08
# 2627   28   0.14   0.11
# 2661  102   1.06   0.64
# 2731   40   0.53   0.58
#
# [22 rows x 28 columns]
