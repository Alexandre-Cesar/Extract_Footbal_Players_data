# %%
from scrappy import Scrapper
import pandas as pd

# %%
url = 'https://fbref.com/en/comps/Big5/stats/players/Big-5-European-Leagues-Stats'

headers = {
        'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.198 Safari/537.36"}

# %%
jogadores = Scrapper(link= url, headers= headers)

def makeDict(self, num_inicial, num_final):
    columns = self.makeCols()
    rows = self.makeContent(num_inicial, num_final) 
    dicionario = {}
    n = len(columns)

    splited = [rows[i::n] for i in range(n)]

    for i in range(0, 35):
        dicionario[columns[i]] = splited[i]

    return dicionario

# %%
dicionario = makeDict(self= jogadores, num_inicial= 0, num_final= 2769)
df = pd.DataFrame(dicionario)
df.head()
# Out:
#              Player   Nation    Pos           Squad                Comp Age  \
# 0  Brenden Aaronson   us USA  MF,FW    Leeds United  eng Premier League  21
# 1   Paxten Aaronson   us USA  MF,DF  Eint Frankfurt       de Bundesliga  18
# 2    James Abankwah   ie IRL     DF         Udinese          it Serie A  18
# 3     George Abbott  eng ENG     MF       Tottenham  eng Premier League  16
# 4  Yunis Abdelhamid   ma MAR     DF           Reims          fr Ligue 1  34
#
#    Born  MP Starts    Min  ... CrdR    xG  npxG   xAG npxG+xAG PrgC PrgP PrgR  \
# 0  2000  36     28  2,372  ...    0  0.15  0.15  0.16      8.1   43   86  151
# 1  2003   7      0    173  ...    0  0.09  0.09  0.03      0.2    8    6   15
# 2  2004   2      1     63  ...    0  0.00  0.00  0.00      0.0    0    0    0
# 3  2005   1      0      1  ...    0  0.00  0.00  0.00      0.0    0    0    0
# 4  1987  37     37  3,330  ...    0  0.06  0.06  0.03      3.4   40  215   10
#
#   G+A-PK xG+xAG
# 0   0.15   0.31
# 1   0.00   0.11
# 2   0.00   0.00
# 3   0.00   0.00
# 4   0.08   0.09
#
# [5 rows x 28 columns]
